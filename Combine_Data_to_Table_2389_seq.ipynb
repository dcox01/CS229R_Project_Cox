# %% [markdown]
# ## Combine_Data_to_Table_2389_seq

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import n_cut.n_cut as nc
import n_cut.MNIST_helper as mh
import pickle
import os

# %%
# Get
os.getcwd()
# Out:
# '/Users/dcox/Dropbox/LDS/Courses/CS_229R/project'

# %%
path = './Exps/2389/seq/'

# %%
file_list = ['df_2389_seq_prune_0_4_64_run',
            'df_2389_seq_prune_0_4_128_run',
            'df_2389_seq_prune_0_4_256_run',
            'df_2389_seq_prune_04_4_64_run',
            'df_2389_seq_prune_04_4_128_run',
            'df_2389_seq_prune_04_4_256_run',
            'df_2389_seq_prune_08_2_32_run',
            'df_2389_seq_prune_08_4_64_run',
            'df_2389_seq_prune_08_4_128_run',
            'df_2389_seq_prune_08_4_256_run']

# %%
dfs = nc.load_dfs_to_list(path, file_list)

# %%
df_combined_2389_seq = nc.make_table(dfs)

# %%
df_combined_2389_seq
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2389        seq         4       64       0.0       1.932      0.027
# 1   2389        seq         4      128       0.0       2.026      0.058
# 2   2389        seq         4      256       0.0       2.119      0.035
# 3   2389        seq         4       64       0.4       1.799      0.063
# 4   2389        seq         4      128       0.4       1.937      0.030
# 5   2389        seq         4      256       0.4       2.065      0.022
# 6   2389        seq         2       32       0.8       1.454      0.159
# 7   2389        seq         4       64       0.8       1.584      0.056
# 8   2389        seq         4      128       0.8       1.834      0.040
# 9   2389        seq         4      256       0.8       1.976      0.050
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.009       1.934           0.028      -0.002   smaller    0.687   No
# ...

# %%
with open('df_combined_2389_seq', 'wb') as fp:
    pickle.dump(df_combined_2389_seq, fp)
    
with open('df_combined_2389_seq', 'rb') as fp:
    df_combined_2389_seq = pickle.load(fp)

# %%
df_combined_2389_seq
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2389        seq         4       64       0.0       1.932      0.027
# 1   2389        seq         4      128       0.0       2.026      0.058
# 2   2389        seq         4      256       0.0       2.119      0.035
# 3   2389        seq         4       64       0.4       1.799      0.063
# 4   2389        seq         4      128       0.4       1.937      0.030
# 5   2389        seq         4      256       0.4       2.065      0.022
# 6   2389        seq         2       32       0.8       1.454      0.159
# 7   2389        seq         4       64       0.8       1.584      0.056
# 8   2389        seq         4      128       0.8       1.834      0.040
# 9   2389        seq         4      256       0.8       1.976      0.050
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.009       1.934           0.028      -0.002   smaller    0.687   No
# ...
