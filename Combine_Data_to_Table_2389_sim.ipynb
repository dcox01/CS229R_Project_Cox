# %% [markdown]
# ## Combine_Data_to_Table_2389_sim

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import n_cut.n_cut as nc
import n_cut.MNIST_helper as mh
import pickle
import os

# %%
# Get
os.getcwd()
# Out:
# '/Users/dcox/Dropbox/LDS/Courses/CS_229R/project'

# %%
path = './Exps/2389/sim/'

# %%
file_list = ['df_2389_sim_prune_0_4_64_run',
            'df_2389_sim_prune_0_4_128_run',
            'df_2389_sim_prune_0_4_256_run',
            'df_2389_sim_prune_04_4_64_run',
            'df_2389_sim_prune_04_4_128_run',
            'df_2389_sim_prune_04_4_256_run',
            'df_2389_sim_prune_08_2_32_run',
            'df_2389_sim_prune_08_4_64_run',
            'df_2389_sim_prune_08_4_128_run',
            'df_2389_sim_prune_08_4_256_run']

# %%
dfs = nc.load_dfs_to_list(path, file_list)

# %%
df_combined_2389_sim = nc.make_table(dfs)

# %%
df_combined_2389_sim
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2389        sim         4       64       0.0       2.200      0.043
# 1   2389        sim         4      128       0.0       2.306      0.038
# 2   2389        sim         4      256       0.0       2.343      0.041
# 3   2389        sim         4       64       0.4       2.054      0.021
# 4   2389        sim         4      128       0.4       2.192      0.020
# 5   2389        sim         4      256       0.4       2.306      0.028
# 6   2389        sim         2       32       0.8       1.885      0.075
# 7   2389        sim         4       64       0.8       1.735      0.050
# 8   2389        sim         4      128       0.8       1.947      0.024
# 9   2389        sim         4      256       0.8       2.121      0.021
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.014       2.177           0.024       0.023    larger    0.077   No
# ...

# %%
with open('df_combined_2389_sim', 'wb') as fp:
    pickle.dump(df_combined_2389_sim, fp)
    
with open('df_combined_2389_sim', 'rb') as fp:
    df_combined_2389_sim = pickle.load(fp)

# %%
df_combined_2389_sim
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2389        sim         4       64       0.0       2.200      0.043
# 1   2389        sim         4      128       0.0       2.306      0.038
# 2   2389        sim         4      256       0.0       2.343      0.041
# 3   2389        sim         4       64       0.4       2.054      0.021
# 4   2389        sim         4      128       0.4       2.192      0.020
# 5   2389        sim         4      256       0.4       2.306      0.028
# 6   2389        sim         2       32       0.8       1.885      0.075
# 7   2389        sim         4       64       0.8       1.735      0.050
# 8   2389        sim         4      128       0.8       1.947      0.024
# 9   2389        sim         4      256       0.8       2.121      0.021
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.014       2.177           0.024       0.023    larger    0.077   No
# ...

# %%
df_combined_2389_sim
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2389        sim         4       64       0.0       2.200      0.043
# 1   2389        sim         4      128       0.0       2.306      0.038
# 2   2389        sim         4      256       0.0       2.343      0.041
# 3   2389        sim         4       64       0.4       2.054      0.021
# 4   2389        sim         4      128       0.4       2.192      0.020
# 5   2389        sim         4      256       0.4       2.306      0.028
# 6   2389        sim         2       32       0.8       1.885      0.075
# 7   2389        sim         4       64       0.8       1.735      0.050
# 8   2389        sim         4      128       0.8       1.947      0.024
# 9   2389        sim         4      256       0.8       2.121      0.021
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.014       2.177           0.024       0.023    larger    0.077   No
# ...
