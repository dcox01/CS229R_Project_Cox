# %% [markdown]
# ## Combine_Data_to_Table_2467_sim

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import n_cut.n_cut as nc
import n_cut.MNIST_helper as mh
import os
import pickle

# %%
# Get
os.getcwd()
# Out:
# '/Users/dcox/Dropbox/LDS/Courses/CS_229R/project'

# %%
path = './Exps/2467/sim/'

# %%
file_list = ['df_2467_sim_prune_0_4_64_run',
            'df_2467_sim_prune_0_4_128_run',
            'df_2467_sim_prune_0_4_256_run',
            'df_2467_sim_prune_04_4_64_run',
            'df_2467_sim_prune_04_4_128_run',
            'df_2467_sim_prune_04_4_256_run',
            'df_2467_sim_prune_08_2_32_run',
            'df_2467_sim_prune_08_4_64_run',
            'df_2467_sim_prune_08_4_128_run',
            'df_2467_sim_prune_08_4_256_run']

# %%
dfs = nc.load_dfs_to_list(path, file_list)

# %%
df_combined_2467_sim = nc.make_table(dfs)

# %%
df_combined_2467_sim
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2467        sim         4       64       0.0       2.182      0.028
# 1   2467        sim         4      128       0.0       2.290      0.045
# 2   2467        sim         4      256       0.0       2.370      0.046
# 3   2467        sim         4       64       0.4       2.070      0.028
# 4   2467        sim         4      128       0.4       2.191      0.019
# 5   2467        sim         4      256       0.4       2.307      0.017
# 6   2467        sim         2       32       0.8       1.915      0.077
# 7   2467        sim         4       64       0.8       1.764      0.033
# 8   2467        sim         4      128       0.8       1.964      0.041
# 9   2467        sim         4      256       0.8       2.126      0.025
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.009       2.168           0.017       0.014    larger    0.160   No
# 1      0.014       2.273           0.040       0.017    larger    0.038  Yes
# 2      0.014       2.304           0.036       0.066    larger    0.001  Yes
# 3      0.009       2.072           0.017      -0.002   smaller    0.711   No
# 4      0.006       2.203           0.014      -0.012   smaller    0.136   No
# 5      0.005       2.296           0.013       0.011    larger    0.022  Yes
# 6      0.024       1.580           0.070       0.335    larger    0.000  Yes
# 7      0.010       1.685           0.019       0.079    larger    0.000  Yes
# 8      0.013       1.973           0.023      -0.009   smaller    0.425   No
# 9      0.008       2.150           0.022      -0.024   smaller    0.004  Yes
#
#    Accuracy
# 0  0.986715
# 1  0.987572
# 2  0.988113
# 3  0.985058
# 4  0.987405
# 5  0.987582
# 6  0.977318
# 7  0.978952
# 8  0.982345
# 9  0.985000

# %%
with open('df_combined_2467_sim', 'wb') as fp:
    pickle.dump(df_combined_2467_sim, fp)
    
with open('df_combined_2467_sim', 'rb') as fp:
    df_combined_2467_sim = pickle.load(fp)

# %%
df_combined_2467_sim
# Out:
#   Series Train_type  H_layers  H_nodes  prunning  Mean_N_cut  N_cut_std  \
# 0   2467        sim         4       64       0.0       2.182      0.028
# 1   2467        sim         4      128       0.0       2.290      0.045
# 2   2467        sim         4      256       0.0       2.370      0.046
# 3   2467        sim         4       64       0.4       2.070      0.028
# 4   2467        sim         4      128       0.4       2.191      0.019
# 5   2467        sim         4      256       0.4       2.307      0.017
# 6   2467        sim         2       32       0.8       1.915      0.077
# 7   2467        sim         4       64       0.8       1.764      0.033
# 8   2467        sim         4      128       0.8       1.964      0.041
# 9   2467        sim         4      256       0.8       2.126      0.025
#
#    N_cut_ste  N_cut_rand  N_cut_rand_std  N_cut_diff Direction  P_value  Sig  \
# 0      0.009       2.168           0.017       0.014    larger    0.160   No
# 1      0.014       2.273           0.040       0.017    larger    0.038  Yes
# 2      0.014       2.304           0.036       0.066    larger    0.001  Yes
# 3      0.009       2.072           0.017      -0.002   smaller    0.711   No
# 4      0.006       2.203           0.014      -0.012   smaller    0.136   No
# 5      0.005       2.296           0.013       0.011    larger    0.022  Yes
# 6      0.024       1.580           0.070       0.335    larger    0.000  Yes
# 7      0.010       1.685           0.019       0.079    larger    0.000  Yes
# 8      0.013       1.973           0.023      -0.009   smaller    0.425   No
# 9      0.008       2.150           0.022      -0.024   smaller    0.004  Yes
#
#    Accuracy
# 0  0.986715
# 1  0.987572
# 2  0.988113
# 3  0.985058
# 4  0.987405
# 5  0.987582
# 6  0.977318
# 7  0.978952
# 8  0.982345
# 9  0.985000
