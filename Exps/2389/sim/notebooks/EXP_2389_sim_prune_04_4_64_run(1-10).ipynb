# %% [markdown]
# ## EXP_2389_sim_prune_04_4_64_run(1-10)
# Dan Cox May 2021 CS299 Project

# %% [markdown]
# #### Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import os
import warnings
from collections import OrderedDict

from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten,Reshape
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tempfile
import n_cut.n_cut as nc
import n_cut.MNIST_helper as mh

# %% [markdown]
# #### Make experiments dict

# %%
exp_dict = OrderedDict()

# %% [markdown]
# #### Get MNIST data

# %%
# Get mnist data split into train and test 60000 x 28 x 28 train, 10000 x 28 x28 test
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# #### Run experiment many times (num_runs)

# %%
# %%time
series = [2,3,8,9]
num_runs = 10
name = '2389_sim_prune_04_4_64_run'
for i in range(num_runs):
    print(f'run {i}')
    full_name = name + str(i)
    model, history = nc.make_train_simultaneous_model(x_train=x_train,
                                  y_train=y_train,
                                  x_test=x_test,
                                  y_test=y_test,
                                  series=series,
                                  num_hidden_layers=4,
                                  num_hidden_nodes=64,
                                  num_output_nodes=4,
                                  pruning=0.4,
                                  epochs=10,
                                  verbose=0,
                                  summary=False)
    
    exp_dict[full_name] = nc.get_n_cuts_and_p_value(
                        model = model,
                        model_history = history,
                        num_clusters=4,
                        random_state=None,
                        identity=False,
                        start=1,
                        num_shuffle_trials=20)
# Out:
# run 0
# WARNING:tensorflow:From /Users/dcox/opt/anaconda3/lib/python3.8/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:215: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /Users/dcox/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0013s vs `on_train_batch_end` time: 0.0166s). Check your callbacks.
# run 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0677s). Check your callbacks.
# run 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0012s vs `on_train_batch_end` time: 0.0709s). Check your callbacks.
# run 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0683s). Check your callbacks.
# run 4
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0012s vs `on_train_batch_begin` time: 0.0045s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0012s vs `on_train_batch_end` time: 0.0922s). Check your callbacks.
# run 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0665s). Check your callbacks.
# run 6
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0011s vs `on_train_batch_end` time: 0.0762s). Check your callbacks.
# run 7
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0681s). Check your callbacks.
# run 8
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0012s vs `on_train_batch_end` time: 0.0728s). Check your callbacks.
# run 9
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_train_batch_end` time: 0.1213s). Check your callbacks.
# CPU times: user 12min 3s, sys: 1min 1s, total: 13min 5s
# Wall time: 14min 40s

# %% [markdown]
# #### Convert Results to a dataframe

# %%
df = pd.DataFrame(exp_dict)
df = df.T
df_models = df.iloc[:, 0]
df.columns = ['model','N_cut','Mean_n_cut_rand', 'Std_n_cut_rand', 'Ste_n_cut_rand', 'Percentile','P_value', 'Significance','Direction', 'Accuracy']
df = df.drop('model', axis=1)
df
# Out:
#                                N_cut Mean_n_cut_rand Std_n_cut_rand  \
# 2389_sim_prune_04_4_64_run0  2.06149           2.066       0.016889
# 2389_sim_prune_04_4_64_run1  2.05088         2.08701      0.0275578
# 2389_sim_prune_04_4_64_run2   2.0466         2.04997      0.0172057
# 2389_sim_prune_04_4_64_run3  2.07669         2.06847      0.0186629
# 2389_sim_prune_04_4_64_run4  2.07779          2.0492      0.0228167
# 2389_sim_prune_04_4_64_run5  2.04498         2.05229      0.0200788
# 2389_sim_prune_04_4_64_run6  2.02902         2.05545      0.0169463
# 2389_sim_prune_04_4_64_run7   2.0546         2.08647      0.0238529
# 2389_sim_prune_04_4_64_run8    2.015         2.04396      0.0240535
# 2389_sim_prune_04_4_64_run9  2.07909         2.06338      0.0138605
#
#                             Ste_n_cut_rand Percentile P_value Significance  \
# 2389_sim_prune_04_4_64_run0      0.0037765         45     0.9           No
# 2389_sim_prune_04_4_64_run1     0.00616212         10     0.2           No
# 2389_sim_prune_04_4_64_run2     0.00384732         40     0.8           No
# 2389_sim_prune_04_4_64_run3     0.00417315         70     0.6           No
# 2389_sim_prune_04_4_64_run4     0.00510197         95     0.1           No
# 2389_sim_prune_04_4_64_run5     0.00448975         35     0.7           No
# 2389_sim_prune_04_4_64_run6     0.00378931         15     0.3           No
# 2389_sim_prune_04_4_64_run7     0.00533368          5     0.1           No
# 2389_sim_prune_04_4_64_run8     0.00537852         20     0.4           No
# 2389_sim_prune_04_4_64_run9      0.0030993         90     0.2           No
#
#                             Direction  Accuracy
# 2389_sim_prune_04_4_64_run0   smaller    0.9826
# 2389_sim_prune_04_4_64_run1   smaller    0.9795
# 2389_sim_prune_04_4_64_run2   smaller   0.98105
# 2389_sim_prune_04_4_64_run3    larger    0.9795
# 2389_sim_prune_04_4_64_run4    larger   0.98025
# 2389_sim_prune_04_4_64_run5   smaller   0.98505
# 2389_sim_prune_04_4_64_run6   smaller    0.9834
# 2389_sim_prune_04_4_64_run7   smaller  0.984225
# 2389_sim_prune_04_4_64_run8   smaller  0.981125
# 2389_sim_prune_04_4_64_run9    larger  0.983425

# %% [markdown]
# #### Save dataframe

# %%
import pickle
with open('df_'+ name, 'wb') as fp:
    pickle.dump(df, fp)
    
with open('df_'+ name, 'rb') as fp:
    df = pickle.load(fp)
df
# Out:
#                                N_cut Mean_n_cut_rand Std_n_cut_rand  \
# 2389_sim_prune_04_4_64_run0  2.06149           2.066       0.016889
# 2389_sim_prune_04_4_64_run1  2.05088         2.08701      0.0275578
# 2389_sim_prune_04_4_64_run2   2.0466         2.04997      0.0172057
# 2389_sim_prune_04_4_64_run3  2.07669         2.06847      0.0186629
# 2389_sim_prune_04_4_64_run4  2.07779          2.0492      0.0228167
# 2389_sim_prune_04_4_64_run5  2.04498         2.05229      0.0200788
# 2389_sim_prune_04_4_64_run6  2.02902         2.05545      0.0169463
# 2389_sim_prune_04_4_64_run7   2.0546         2.08647      0.0238529
# 2389_sim_prune_04_4_64_run8    2.015         2.04396      0.0240535
# 2389_sim_prune_04_4_64_run9  2.07909         2.06338      0.0138605
#
#                             Ste_n_cut_rand Percentile P_value Significance  \
# 2389_sim_prune_04_4_64_run0      0.0037765         45     0.9           No
# 2389_sim_prune_04_4_64_run1     0.00616212         10     0.2           No
# 2389_sim_prune_04_4_64_run2     0.00384732         40     0.8           No
# 2389_sim_prune_04_4_64_run3     0.00417315         70     0.6           No
# 2389_sim_prune_04_4_64_run4     0.00510197         95     0.1           No
# 2389_sim_prune_04_4_64_run5     0.00448975         35     0.7           No
# 2389_sim_prune_04_4_64_run6     0.00378931         15     0.3           No
# 2389_sim_prune_04_4_64_run7     0.00533368          5     0.1           No
# 2389_sim_prune_04_4_64_run8     0.00537852         20     0.4           No
# 2389_sim_prune_04_4_64_run9      0.0030993         90     0.2           No
#
#                             Direction  Accuracy
# 2389_sim_prune_04_4_64_run0   smaller    0.9826
# 2389_sim_prune_04_4_64_run1   smaller    0.9795
# 2389_sim_prune_04_4_64_run2   smaller   0.98105
# 2389_sim_prune_04_4_64_run3    larger    0.9795
# 2389_sim_prune_04_4_64_run4    larger   0.98025
# 2389_sim_prune_04_4_64_run5   smaller   0.98505
# 2389_sim_prune_04_4_64_run6   smaller    0.9834
# 2389_sim_prune_04_4_64_run7   smaller  0.984225
# 2389_sim_prune_04_4_64_run8   smaller  0.981125
# 2389_sim_prune_04_4_64_run9    larger  0.983425

# %%
df_models[0].layers[1].get_weights()[0]
# Out:
# array([[ 0.        , -0.03492282,  0.04298996, ...,  0.05026484,
#         -0.        ,  0.04867569],
#        [ 0.06830759,  0.0662099 ,  0.04363171, ..., -0.        ,
#         -0.        ,  0.04080293],
#        [ 0.        ,  0.06188106, -0.04469486, ...,  0.        ,
#         -0.05036885,  0.04855082],
#        ...,
#        [ 0.        , -0.04525338,  0.        , ...,  0.05519847,
#          0.        , -0.07759544],
#        [ 0.        , -0.        ,  0.        , ...,  0.06019912,
#         -0.05123785, -0.        ],
#        [ 0.04578327,  0.03652422, -0.        , ...,  0.        ,
#         -0.        , -0.        ]], dtype=float32)

# %% [markdown]
# #### Look at results of first experiment

# %%
for val in exp_dict[name + str(0)]:
    print(val)
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f87e94f0f70>
# 2.0614852842170603
# 2.0660036114412015
# 0.016888999230129414
# 0.0037764950350510982
# 45.0
# 0.9
# No
# smaller
# 0.9825999736785889
